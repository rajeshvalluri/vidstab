# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshvalluri/vidstab/blob/main/VidStab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from timeit import default_timer as timer

# %%
start_time = timer()

# %% [markdown]
# **Helper Function to detect blur in frames**

# %%
def detect_blur_fft(image, size=60, thresh=10, vis=False):
	# grab the dimensions of the image and use the dimensions to
	# derive the center (x, y)-coordinates
	(h, w) = image.shape
	(cX, cY) = (int(w / 2.0), int(h / 2.0))

	# compute the FFT to find the frequency transform, then shift
	# the zero frequency component (i.e., DC component located at
	# the top-left corner) to the center where it will be more
	# easy to analyze
	fft = np.fft.fft2(image)
	fftShift = np.fft.fftshift(fft)

	# check to see if we are visualizing our output
	if vis:
		# compute the magnitude spectrum of the transform
		magnitude = 20 * np.log(np.abs(fftShift))

		# display the original input image
		(fig, ax) = plt.subplots(1, 2, )
		ax[0].imshow(image, cmap="gray")
		ax[0].set_title("Input")
		ax[0].set_xticks([])
		ax[0].set_yticks([])

		# display the magnitude image
		ax[1].imshow(magnitude, cmap="gray")
		ax[1].set_title("Magnitude Spectrum")
		ax[1].set_xticks([])
		ax[1].set_yticks([])

		# show our plots
		plt.show()

	# zero-out the center of the FFT shift (i.e., remove low
	# frequencies), apply the inverse shift such that the DC
	# component once again becomes the top-left, and then apply
	# the inverse FFT
	fftShift[cY - size:cY + size, cX - size:cX + size] = 0
	fftShift = np.fft.ifftshift(fftShift)
	recon = np.fft.ifft2(fftShift)

	# compute the magnitude spectrum of the reconstructed image,
	# then compute the mean of the magnitude values
	magnitude = 20 * np.log(np.abs(recon))
	mean = np.mean(magnitude)

	# the image will be considered "blurry" if the mean value of the
	# magnitudes is less than the threshold value
	return (mean, mean <= thresh)

# %% [markdown]
# **Connect to google drive to load video files**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cap = cv2.VideoCapture('/content/gdrive/MyDrive/vidstab/CarVideo.mp4')
#get the basic information about the video, like the frame rate(fps), frame_count height and the width
fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
print(cap.get(3),cap.get(4))
# Out:
# 1280.0 720.0

# %%
#print details acquired above for sanity checks
print("Frame Count:", frame_count, "Width :", width,"Height :",height," at a frame rate of:",fps)
# Out:
# Frame Count: 714 Width : 1280 Height : 720  at a frame rate of: 7.9466778657196935

# %%
#setting up a format and profile for output video
#start by defining four character code for encoding
fourcc = cv2.VideoWriter_fourcc(*'MJPG') #MJPG gives the highest resolution image/video

output_video = cv2.VideoWriter('/content/gdrive/MyDrive/vidstab/CarVideo_output.mp4', fourcc,fps, (width, height))

# %%
#once the basics have been done, time to start going through each frame and detect motion
#read a frame
_, prev = cap.read()
print(prev.shape)
#convert the frames to grayscale for easy computations 3-channel info will be flattned to a single channel one
prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY)
print(prev_gray[719])
# Out:
# (720, 1280, 3)
# [ 46  51  59 ...  86  68 129]

# %%
print(prev)

# %%
#start the process of identifying the right features to track, and estimate motion between frames
transforms = np.zeros((frame_count-1,3), np.float32) # 3 deltas to track x, y and z axis movements
# we only need frame_count -1 number of transformations because the last frame doesn't need anymore transformations
print(transforms.shape)
# Out:
# (713, 3)

# %%
#use the blur_detector helper method to filter out blurry frames
cap.set(cv2.CAP_PROP_POS_FRAMES, 0) 
blurry_frames = []
blurry_idx = []
for i in range(frame_count -2):
  #read the next frame
  success, curr = cap.read()
  if (not success): # no more frames to read or read failed
    break 
  curr_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY)
  #if (detect_blur_fft(curr_gray)[1]):
  #  print('Blurry Frame')
  #np.asarray(blurry_frames,detect_blur_fft(curr_gray))
  mean_thresh, blurry = detect_blur_fft(curr_gray,thresh=25)
  if (blurry == True):
    print(mean_thresh,blurry)
    blurry_frames.append(curr)
    blurry_idx.append(i)
    #print("Frame no.", i,"is Blurry")
    #(fig, ax) = plt.subplots(1, 1)
    #ax.imshow(curr)
    #print(curr.shape)
  #plt.show()
# Out:
# 24.7043704714652 True
# 24.843227079297783 True
# 24.79946042342459 True
# 24.82582139670966 True
# 24.773751749710424 True
# 24.635941800958996 True
# 24.965761077090576 True
# 24.559599540960868 True
# 24.15098778001376 True
# 23.365388959623896 True
# 23.74459279939049 True
# 23.902943455802994 True
# 23.684824659119904 True
# 22.989447642512175 True
# 22.5984281475603 True
# 21.50498453432441 True
# 23.358729191390417 True
# 24.0186890174136 True
# 23.230402250399152 True
# 22.861249706946396 True
# 22.734735451333247 True
# 23.18418380753202 True
# 22.421725177114975 True
# 22.75423690247001 True
# 22.92154277372427 True
# 22.352759429691186 True
# 22.16115522393123 True
# 22.954498252739494 True
# 22.73647401335291 True
# 22.665763259965104 True
# 22.630760187262716 True
# 22.662505179687283 True
# 22.397019129509037 True
# 23.415235135617753 True
# 22.459465890054748 True
# 23.084905597228204 True
# 22.733209369586717 True
# 23.542849546046664 True
# 23.518177821306967 True
# 23.570826279292977 True
# 23.245400312638395 True
# 23.572070899600686 True
# 23.793909636530394 True
# 24.174175418308568 True
# 24.355864112417404 True
# 24.24420602200271 True
# 24.30895457093329 True
# 24.762663570522733 True
# 24.288861311205796 True
# 24.78954886080892 True
# 24.59753399059301 True
# 24.356515240672202 True
# 24.288436260628252 True
# 24.922976816418327 True
# 24.907212617855446 True
# 23.73750046558025 True
# 23.806597797128507 True
# 24.267082470173325 True
# 24.081149722500903 True

# %%
print(len(blurry_frames),blurry_idx)
# Out:
# 59 [500, 501, 502, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 556, 557, 558, 559, 560, 561, 562, 563]

# %%
print(blurry_frames)

# %%
#use CV2's goodFeaturesToTrack method to get features
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
for i in range(frame_count -2):
  prev_points = cv2.goodFeaturesToTrack(prev_gray,
                                        maxCorners=200,
                                        qualityLevel=0.01,
                                        minDistance=30,
                                        blockSize=3)
  #read the next frame
  success, curr = cap.read()
  if (not success): # no more frames to read or read failed
    break 
  mean_thresh, blurry = detect_blur_fft(curr_gray,thresh=25)
  if (blurry == True):
    continue
  curr_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY)
  #use CV2's opticalflowpyrLK ( Pyramid  Lucas-Kanade  ) method to compute optical flow between current and previous frames
  curr_points, status, err = cv2.calcOpticalFlowPyrLK(prev_gray, curr_gray,prev_points, None )
  #print ( prev_points.shape, curr_points.shape)
  #print(status.shape)
  idx = np.where( status ==1)[0]
  #culling the previous points and current points arrays to only use the valid ones
  prev_points = prev_points[idx]
  curr_points = curr_points[idx]
  matrix, _ = cv2.estimateAffinePartial2D(prev_points, curr_points)
  print (matrix.shape)
  x_movement = matrix[0][2]
  y_movement = matrix[1][2]
  angle_change = np.arctan2(matrix[1][0],matrix[0][0])
  transforms[i] = [x_movement,y_movement,angle_change]
  #get next frame
  prev_gray = curr_gray
  print("Frame : ", i , "/" , frame_count, " - Tracked points: ", len(prev_points))
# Out:
# (2, 3)
# Frame :  0 / 714  - Tracked points:  200
# (2, 3)
# Frame :  1 / 714  - Tracked points:  179
# (2, 3)
# Frame :  2 / 714  - Tracked points:  200
# (2, 3)
# Frame :  3 / 714  - Tracked points:  189
# (2, 3)
# Frame :  4 / 714  - Tracked points:  200
# (2, 3)
# Frame :  5 / 714  - Tracked points:  199
# (2, 3)
# Frame :  6 / 714  - Tracked points:  197
# (2, 3)
# Frame :  7 / 714  - Tracked points:  200
# (2, 3)
# Frame :  8 / 714  - Tracked points:  199
# (2, 3)
# Frame :  9 / 714  - Tracked points:  200
# (2, 3)
# Frame :  10 / 714  - Tracked points:  200
# (2, 3)
# Frame :  11 / 714  - Tracked points:  200
# (2, 3)
# Frame :  12 / 714  - Tracked points:  196
# (2, 3)
# Frame :  13 / 714  - Tracked points:  193
# (2, 3)
# Frame :  14 / 714  - Tracked points:  198
# (2, 3)
# Frame :  15 / 714  - Tracked points:  200
# (2, 3)
# Frame :  16 / 714  - Tracked points:  200
# (2, 3)
# Frame :  17 / 714  - Tracked points:  200
# (2, 3)
# Frame :  18 / 714  - Tracked points:  189
# (2, 3)
# Frame :  19 / 714  - Tracked points:  196
# (2, 3)
# Frame :  20 / 714  - Tracked points:  193
# (2, 3)
# Frame :  21 / 714  - Tracked points:  198
# (2, 3)
# Frame :  22 / 714  - Tracked points:  194
# (2, 3)
# Frame :  23 / 714  - Tracked points:  176
# (2, 3)
# Frame :  24 / 714  - Tracked points:  199
# (2, 3)
# Frame :  25 / 714  - Tracked points:  199
# (2, 3)
# Frame :  26 / 714  - Tracked points:  199
# (2, 3)
# Frame :  27 / 714  - Tracked points:  197
# (2, 3)
# Frame :  28 / 714  - Tracked points:  196
# (2, 3)
# Frame :  29 / 714  - Tracked points:  200
# (2, 3)
# Frame :  30 / 714  - Tracked points:  200
# (2, 3)
# Frame :  31 / 714  - Tracked points:  198
# (2, 3)
# Frame :  32 / 714  - Tracked points:  196
# (2, 3)
# Frame :  33 / 714  - Tracked points:  198
# (2, 3)
# Frame :  34 / 714  - Tracked points:  191
# (2, 3)
# Frame :  35 / 714  - Tracked points:  186
# (2, 3)
# Frame :  36 / 714  - Tracked points:  175
# (2, 3)
# Frame :  37 / 714  - Tracked points:  191
# (2, 3)
# Frame :  38 / 714  - Tracked points:  189
# (2, 3)
# Frame :  39 / 714  - Tracked points:  198
# (2, 3)
# Frame :  40 / 714  - Tracked points:  193
# (2, 3)
# Frame :  41 / 714  - Tracked points:  172
# (2, 3)
# Frame :  42 / 714  - Tracked points:  177
# (2, 3)
# Frame :  43 / 714  - Tracked points:  188
# (2, 3)
# Frame :  44 / 714  - Tracked points:  166
# (2, 3)
# Frame :  45 / 714  - Tracked points:  180
# (2, 3)
# Frame :  46 / 714  - Tracked points:  188
# (2, 3)
# Frame :  47 / 714  - Tracked points:  165
# (2, 3)
# Frame :  48 / 714  - Tracked points:  180
# (2, 3)
# Frame :  49 / 714  - Tracked points:  191
# (2, 3)
# Frame :  50 / 714  - Tracked points:  196
# (2, 3)
# Frame :  51 / 714  - Tracked points:  197
# (2, 3)
# Frame :  52 / 714  - Tracked points:  183
# (2, 3)
# Frame :  53 / 714  - Tracked points:  161
# (2, 3)
# Frame :  54 / 714  - Tracked points:  188
# (2, 3)
# Frame :  55 / 714  - Tracked points:  177
# (2, 3)
# Frame :  56 / 714  - Tracked points:  199
# (2, 3)
# Frame :  57 / 714  - Tracked points:  191
# (2, 3)
# Frame :  58 / 714  - Tracked points:  197
# (2, 3)
# Frame :  59 / 714  - Tracked points:  186
# (2, 3)
# Frame :  60 / 714  - Tracked points:  173
# (2, 3)
# Frame :  61 / 714  - Tracked points:  190
# (2, 3)
# Frame :  62 / 714  - Tracked points:  188
# (2, 3)
# Frame :  63 / 714  - Tracked points:  196
# (2, 3)
# Frame :  64 / 714  - Tracked points:  200
# (2, 3)
# Frame :  65 / 714  - Tracked points:  200
# (2, 3)
# Frame :  66 / 714  - Tracked points:  200
# (2, 3)
# Frame :  67 / 714  - Tracked points:  198
# (2, 3)
# Frame :  68 / 714  - Tracked points:  199
# (2, 3)
# Frame :  69 / 714  - Tracked points:  198
# (2, 3)
# Frame :  70 / 714  - Tracked points:  193
# (2, 3)
# Frame :  71 / 714  - Tracked points:  181
# (2, 3)
# Frame :  72 / 714  - Tracked points:  193
# (2, 3)
# Frame :  73 / 714  - Tracked points:  192
# (2, 3)
# Frame :  74 / 714  - Tracked points:  187
# (2, 3)
# Frame :  75 / 714  - Tracked points:  194
# (2, 3)
# Frame :  76 / 714  - Tracked points:  193
# (2, 3)
# Frame :  77 / 714  - Tracked points:  197
# (2, 3)
# Frame :  78 / 714  - Tracked points:  200
# (2, 3)
# Frame :  79 / 714  - Tracked points:  199
# (2, 3)
# Frame :  80 / 714  - Tracked points:  198
# (2, 3)
# Frame :  81 / 714  - Tracked points:  198
# (2, 3)
# Frame :  82 / 714  - Tracked points:  188
# (2, 3)
# Frame :  83 / 714  - Tracked points:  195
# (2, 3)
# Frame :  84 / 714  - Tracked points:  195
# (2, 3)
# Frame :  85 / 714  - Tracked points:  200
# (2, 3)
# Frame :  86 / 714  - Tracked points:  199
# (2, 3)
# Frame :  87 / 714  - Tracked points:  198
# (2, 3)
# Frame :  88 / 714  - Tracked points:  179
# (2, 3)
# Frame :  89 / 714  - Tracked points:  196
# (2, 3)
# Frame :  90 / 714  - Tracked points:  196
# (2, 3)
# Frame :  91 / 714  - Tracked points:  196
# (2, 3)
# Frame :  92 / 714  - Tracked points:  199
# (2, 3)
# Frame :  93 / 714  - Tracked points:  199
# (2, 3)
# Frame :  94 / 714  - Tracked points:  200
# (2, 3)
# Frame :  95 / 714  - Tracked points:  187
# (2, 3)
# Frame :  96 / 714  - Tracked points:  199
# (2, 3)
# Frame :  97 / 714  - Tracked points:  194
# (2, 3)
# Frame :  98 / 714  - Tracked points:  200
# (2, 3)
# Frame :  99 / 714  - Tracked points:  191
# (2, 3)
# Frame :  100 / 714  - Tracked points:  186
# (2, 3)
# Frame :  101 / 714  - Tracked points:  182
# (2, 3)
# Frame :  102 / 714  - Tracked points:  197
# (2, 3)
# Frame :  103 / 714  - Tracked points:  200
# (2, 3)
# Frame :  104 / 714  - Tracked points:  191
# (2, 3)
# Frame :  105 / 714  - Tracked points:  200
# (2, 3)
# Frame :  106 / 714  - Tracked points:  200
# (2, 3)
# Frame :  107 / 714  - Tracked points:  200
# (2, 3)
# Frame :  108 / 714  - Tracked points:  200
# (2, 3)
# Frame :  109 / 714  - Tracked points:  191
# (2, 3)
# Frame :  110 / 714  - Tracked points:  198
# (2, 3)
# Frame :  111 / 714  - Tracked points:  184
# (2, 3)
# Frame :  112 / 714  - Tracked points:  197
# (2, 3)
# Frame :  113 / 714  - Tracked points:  193
# (2, 3)
# Frame :  114 / 714  - Tracked points:  198
# (2, 3)
# Frame :  115 / 714  - Tracked points:  200
# (2, 3)
# Frame :  116 / 714  - Tracked points:  200
# (2, 3)
# Frame :  117 / 714  - Tracked points:  199
# (2, 3)
# Frame :  118 / 714  - Tracked points:  197
# (2, 3)
# Frame :  119 / 714  - Tracked points:  199
# (2, 3)
# Frame :  120 / 714  - Tracked points:  200
# (2, 3)
# Frame :  121 / 714  - Tracked points:  189
# (2, 3)
# Frame :  122 / 714  - Tracked points:  200
# (2, 3)
# Frame :  123 / 714  - Tracked points:  200
# (2, 3)
# Frame :  124 / 714  - Tracked points:  200
# (2, 3)
# Frame :  125 / 714  - Tracked points:  200
# (2, 3)
# Frame :  126 / 714  - Tracked points:  197
# (2, 3)
# Frame :  127 / 714  - Tracked points:  198
# (2, 3)
# Frame :  128 / 714  - Tracked points:  197
# (2, 3)
# Frame :  129 / 714  - Tracked points:  200
# (2, 3)
# Frame :  130 / 714  - Tracked points:  187
# (2, 3)
# Frame :  131 / 714  - Tracked points:  165
# (2, 3)
# Frame :  132 / 714  - Tracked points:  188
# (2, 3)
# Frame :  133 / 714  - Tracked points:  193
# (2, 3)
# Frame :  134 / 714  - Tracked points:  198
# (2, 3)
# Frame :  135 / 714  - Tracked points:  174
# (2, 3)
# Frame :  136 / 714  - Tracked points:  187
# (2, 3)
# Frame :  137 / 714  - Tracked points:  193
# (2, 3)
# Frame :  138 / 714  - Tracked points:  199
# (2, 3)
# Frame :  139 / 714  - Tracked points:  187
# (2, 3)
# Frame :  140 / 714  - Tracked points:  186
# (2, 3)
# Frame :  141 / 714  - Tracked points:  186
# (2, 3)
# Frame :  142 / 714  - Tracked points:  183
# (2, 3)
# Frame :  143 / 714  - Tracked points:  183
# (2, 3)
# Frame :  144 / 714  - Tracked points:  192
# (2, 3)
# Frame :  145 / 714  - Tracked points:  200
# (2, 3)
# Frame :  146 / 714  - Tracked points:  199
# (2, 3)
# Frame :  147 / 714  - Tracked points:  190
# (2, 3)
# Frame :  148 / 714  - Tracked points:  185
# (2, 3)
# Frame :  149 / 714  - Tracked points:  191
# (2, 3)
# Frame :  150 / 714  - Tracked points:  193
# (2, 3)
# Frame :  151 / 714  - Tracked points:  197
# (2, 3)
# Frame :  152 / 714  - Tracked points:  199
# (2, 3)
# Frame :  153 / 714  - Tracked points:  192
# (2, 3)
# Frame :  154 / 714  - Tracked points:  200
# (2, 3)
# Frame :  155 / 714  - Tracked points:  195
# (2, 3)
# Frame :  156 / 714  - Tracked points:  191
# (2, 3)
# Frame :  157 / 714  - Tracked points:  198
# (2, 3)
# Frame :  158 / 714  - Tracked points:  196
# (2, 3)
# Frame :  159 / 714  - Tracked points:  191
# (2, 3)
# Frame :  160 / 714  - Tracked points:  191
# (2, 3)
# Frame :  161 / 714  - Tracked points:  196
# (2, 3)
# Frame :  162 / 714  - Tracked points:  197
# (2, 3)
# Frame :  163 / 714  - Tracked points:  189
# (2, 3)
# Frame :  164 / 714  - Tracked points:  200
# (2, 3)
# Frame :  165 / 714  - Tracked points:  196
# (2, 3)
# Frame :  166 / 714  - Tracked points:  200
# (2, 3)
# Frame :  167 / 714  - Tracked points:  198
# (2, 3)
# Frame :  168 / 714  - Tracked points:  195
# (2, 3)
# Frame :  169 / 714  - Tracked points:  198
# (2, 3)
# Frame :  170 / 714  - Tracked points:  198
# (2, 3)
# Frame :  171 / 714  - Tracked points:  179
# (2, 3)
# Frame :  172 / 714  - Tracked points:  197
# (2, 3)
# Frame :  173 / 714  - Tracked points:  200
# (2, 3)
# Frame :  174 / 714  - Tracked points:  200
# (2, 3)
# Frame :  175 / 714  - Tracked points:  200
# (2, 3)
# Frame :  176 / 714  - Tracked points:  199
# (2, 3)
# Frame :  177 / 714  - Tracked points:  200
# (2, 3)
# Frame :  178 / 714  - Tracked points:  200
# (2, 3)
# Frame :  179 / 714  - Tracked points:  194
# (2, 3)
# Frame :  180 / 714  - Tracked points:  195
# (2, 3)
# Frame :  181 / 714  - Tracked points:  198
# (2, 3)
# Frame :  182 / 714  - Tracked points:  191
# (2, 3)
# Frame :  183 / 714  - Tracked points:  196
# (2, 3)
# Frame :  184 / 714  - Tracked points:  200
# (2, 3)
# Frame :  185 / 714  - Tracked points:  196
# (2, 3)
# Frame :  186 / 714  - Tracked points:  200
# (2, 3)
# Frame :  187 / 714  - Tracked points:  200
# (2, 3)
# Frame :  188 / 714  - Tracked points:  196
# (2, 3)
# Frame :  189 / 714  - Tracked points:  196
# (2, 3)
# Frame :  190 / 714  - Tracked points:  200
# (2, 3)
# Frame :  191 / 714  - Tracked points:  198
# (2, 3)
# Frame :  192 / 714  - Tracked points:  200
# (2, 3)
# Frame :  193 / 714  - Tracked points:  200
# (2, 3)
# Frame :  194 / 714  - Tracked points:  187
# (2, 3)
# Frame :  195 / 714  - Tracked points:  190
# (2, 3)
# Frame :  196 / 714  - Tracked points:  195
# (2, 3)
# Frame :  197 / 714  - Tracked points:  187
# (2, 3)
# Frame :  198 / 714  - Tracked points:  199
# (2, 3)
# Frame :  199 / 714  - Tracked points:  191
# (2, 3)
# Frame :  200 / 714  - Tracked points:  194
# (2, 3)
# Frame :  201 / 714  - Tracked points:  169
# (2, 3)
# Frame :  202 / 714  - Tracked points:  199
# (2, 3)
# Frame :  203 / 714  - Tracked points:  184
# (2, 3)
# Frame :  204 / 714  - Tracked points:  181
# (2, 3)
# Frame :  205 / 714  - Tracked points:  183
# (2, 3)
# Frame :  206 / 714  - Tracked points:  157
# (2, 3)
# Frame :  207 / 714  - Tracked points:  196
# (2, 3)
# Frame :  208 / 714  - Tracked points:  194
# (2, 3)
# Frame :  209 / 714  - Tracked points:  197
# (2, 3)
# Frame :  210 / 714  - Tracked points:  182
# (2, 3)
# Frame :  211 / 714  - Tracked points:  195
# (2, 3)
# Frame :  212 / 714  - Tracked points:  185
# (2, 3)
# Frame :  213 / 714  - Tracked points:  178
# (2, 3)
# Frame :  214 / 714  - Tracked points:  198
# (2, 3)
# Frame :  215 / 714  - Tracked points:  199
# (2, 3)
# Frame :  216 / 714  - Tracked points:  186
# (2, 3)
# Frame :  217 / 714  - Tracked points:  161
# (2, 3)
# Frame :  218 / 714  - Tracked points:  196
# (2, 3)
# Frame :  219 / 714  - Tracked points:  196
# (2, 3)
# Frame :  220 / 714  - Tracked points:  192
# (2, 3)
# Frame :  221 / 714  - Tracked points:  192
# (2, 3)
# Frame :  222 / 714  - Tracked points:  182
# (2, 3)
# Frame :  223 / 714  - Tracked points:  200
# (2, 3)
# Frame :  224 / 714  - Tracked points:  191
# (2, 3)
# Frame :  225 / 714  - Tracked points:  200
# (2, 3)
# Frame :  226 / 714  - Tracked points:  188
# (2, 3)
# Frame :  227 / 714  - Tracked points:  198
# (2, 3)
# Frame :  228 / 714  - Tracked points:  193
# (2, 3)
# Frame :  229 / 714  - Tracked points:  191
# (2, 3)
# Frame :  230 / 714  - Tracked points:  196
# (2, 3)
# Frame :  231 / 714  - Tracked points:  196
# (2, 3)
# Frame :  232 / 714  - Tracked points:  197
# (2, 3)
# Frame :  233 / 714  - Tracked points:  188
# (2, 3)
# Frame :  234 / 714  - Tracked points:  195
# (2, 3)
# Frame :  235 / 714  - Tracked points:  200
# (2, 3)
# Frame :  236 / 714  - Tracked points:  199
# (2, 3)
# Frame :  237 / 714  - Tracked points:  200
# (2, 3)
# Frame :  238 / 714  - Tracked points:  197
# (2, 3)
# Frame :  239 / 714  - Tracked points:  199
# (2, 3)
# Frame :  240 / 714  - Tracked points:  199
# (2, 3)
# Frame :  241 / 714  - Tracked points:  198
# (2, 3)
# Frame :  242 / 714  - Tracked points:  191
# (2, 3)
# Frame :  243 / 714  - Tracked points:  187
# (2, 3)
# Frame :  244 / 714  - Tracked points:  192
# (2, 3)
# Frame :  245 / 714  - Tracked points:  189
# (2, 3)
# Frame :  246 / 714  - Tracked points:  199
# (2, 3)
# Frame :  247 / 714  - Tracked points:  196
# (2, 3)
# Frame :  248 / 714  - Tracked points:  200
# (2, 3)
# Frame :  249 / 714  - Tracked points:  198
# (2, 3)
# Frame :  250 / 714  - Tracked points:  197
# (2, 3)
# Frame :  251 / 714  - Tracked points:  195
# (2, 3)
# Frame :  252 / 714  - Tracked points:  199
# (2, 3)
# Frame :  253 / 714  - Tracked points:  200
# (2, 3)
# Frame :  254 / 714  - Tracked points:  198
# (2, 3)
# Frame :  255 / 714  - Tracked points:  195
# (2, 3)
# Frame :  256 / 714  - Tracked points:  193
# (2, 3)
# Frame :  257 / 714  - Tracked points:  199
# (2, 3)
# Frame :  258 / 714  - Tracked points:  200
# (2, 3)
# Frame :  259 / 714  - Tracked points:  197
# (2, 3)
# Frame :  260 / 714  - Tracked points:  192
# (2, 3)
# Frame :  261 / 714  - Tracked points:  197
# (2, 3)
# Frame :  262 / 714  - Tracked points:  193
# (2, 3)
# Frame :  263 / 714  - Tracked points:  198
# (2, 3)
# Frame :  264 / 714  - Tracked points:  195
# (2, 3)
# Frame :  265 / 714  - Tracked points:  195
# (2, 3)
# Frame :  266 / 714  - Tracked points:  200
# (2, 3)
# Frame :  267 / 714  - Tracked points:  200
# (2, 3)
# Frame :  268 / 714  - Tracked points:  181
# (2, 3)
# Frame :  269 / 714  - Tracked points:  180
# (2, 3)
# Frame :  270 / 714  - Tracked points:  187
# (2, 3)
# Frame :  271 / 714  - Tracked points:  183
# (2, 3)
# Frame :  272 / 714  - Tracked points:  191
# (2, 3)
# Frame :  273 / 714  - Tracked points:  199
# (2, 3)
# Frame :  274 / 714  - Tracked points:  188
# (2, 3)
# Frame :  275 / 714  - Tracked points:  195
# (2, 3)
# Frame :  276 / 714  - Tracked points:  172
# (2, 3)
# Frame :  277 / 714  - Tracked points:  189
# (2, 3)
# Frame :  278 / 714  - Tracked points:  199
# (2, 3)
# Frame :  279 / 714  - Tracked points:  198
# (2, 3)
# Frame :  280 / 714  - Tracked points:  184
# (2, 3)
# Frame :  281 / 714  - Tracked points:  190
# (2, 3)
# Frame :  282 / 714  - Tracked points:  191
# (2, 3)
# Frame :  283 / 714  - Tracked points:  198
# (2, 3)
# Frame :  284 / 714  - Tracked points:  200
# (2, 3)
# Frame :  285 / 714  - Tracked points:  186
# (2, 3)
# Frame :  286 / 714  - Tracked points:  195
# (2, 3)
# Frame :  287 / 714  - Tracked points:  197
# (2, 3)
# Frame :  288 / 714  - Tracked points:  192
# (2, 3)
# Frame :  289 / 714  - Tracked points:  192
# (2, 3)
# Frame :  290 / 714  - Tracked points:  195
# (2, 3)
# Frame :  291 / 714  - Tracked points:  189
# (2, 3)
# Frame :  292 / 714  - Tracked points:  198
# (2, 3)
# Frame :  293 / 714  - Tracked points:  192
# (2, 3)
# Frame :  294 / 714  - Tracked points:  192
# (2, 3)
# Frame :  295 / 714  - Tracked points:  194
# (2, 3)
# Frame :  296 / 714  - Tracked points:  191
# (2, 3)
# Frame :  297 / 714  - Tracked points:  187
# (2, 3)
# Frame :  298 / 714  - Tracked points:  197
# (2, 3)
# Frame :  299 / 714  - Tracked points:  199
# (2, 3)
# Frame :  300 / 714  - Tracked points:  185
# (2, 3)
# Frame :  301 / 714  - Tracked points:  199
# (2, 3)
# Frame :  302 / 714  - Tracked points:  197
# (2, 3)
# Frame :  303 / 714  - Tracked points:  198
# (2, 3)
# Frame :  304 / 714  - Tracked points:  199
# (2, 3)
# Frame :  305 / 714  - Tracked points:  188
# (2, 3)
# Frame :  306 / 714  - Tracked points:  193
# (2, 3)
# Frame :  307 / 714  - Tracked points:  195
# (2, 3)
# Frame :  308 / 714  - Tracked points:  198
# (2, 3)
# Frame :  309 / 714  - Tracked points:  200
# (2, 3)
# Frame :  310 / 714  - Tracked points:  197
# (2, 3)
# Frame :  311 / 714  - Tracked points:  197
# (2, 3)
# Frame :  312 / 714  - Tracked points:  200
# (2, 3)
# Frame :  313 / 714  - Tracked points:  195
# (2, 3)
# Frame :  314 / 714  - Tracked points:  192
# (2, 3)
# Frame :  315 / 714  - Tracked points:  177
# (2, 3)
# Frame :  316 / 714  - Tracked points:  198
# (2, 3)
# Frame :  317 / 714  - Tracked points:  194
# (2, 3)
# Frame :  318 / 714  - Tracked points:  200
# (2, 3)
# Frame :  319 / 714  - Tracked points:  190
# (2, 3)
# Frame :  320 / 714  - Tracked points:  193
# (2, 3)
# Frame :  321 / 714  - Tracked points:  190
# (2, 3)
# Frame :  322 / 714  - Tracked points:  200
# (2, 3)
# Frame :  323 / 714  - Tracked points:  193
# (2, 3)
# Frame :  324 / 714  - Tracked points:  195
# (2, 3)
# Frame :  325 / 714  - Tracked points:  182
# (2, 3)
# Frame :  326 / 714  - Tracked points:  193
# (2, 3)
# Frame :  327 / 714  - Tracked points:  198
# (2, 3)
# Frame :  328 / 714  - Tracked points:  195
# (2, 3)
# Frame :  329 / 714  - Tracked points:  183
# (2, 3)
# Frame :  330 / 714  - Tracked points:  200
# (2, 3)
# Frame :  331 / 714  - Tracked points:  198
# (2, 3)
# Frame :  332 / 714  - Tracked points:  194
# (2, 3)
# Frame :  333 / 714  - Tracked points:  198
# (2, 3)
# Frame :  334 / 714  - Tracked points:  170
# (2, 3)
# Frame :  335 / 714  - Tracked points:  187
# (2, 3)
# Frame :  336 / 714  - Tracked points:  186
# (2, 3)
# Frame :  337 / 714  - Tracked points:  189
# (2, 3)
# Frame :  338 / 714  - Tracked points:  179
# (2, 3)
# Frame :  339 / 714  - Tracked points:  194
# (2, 3)
# Frame :  340 / 714  - Tracked points:  180
# (2, 3)
# Frame :  341 / 714  - Tracked points:  183
# (2, 3)
# Frame :  342 / 714  - Tracked points:  176
# (2, 3)
# Frame :  343 / 714  - Tracked points:  198
# (2, 3)
# Frame :  344 / 714  - Tracked points:  197
# (2, 3)
# Frame :  345 / 714  - Tracked points:  182
# (2, 3)
# Frame :  346 / 714  - Tracked points:  196
# (2, 3)
# Frame :  347 / 714  - Tracked points:  200
# (2, 3)
# Frame :  348 / 714  - Tracked points:  196
# (2, 3)
# Frame :  349 / 714  - Tracked points:  196
# (2, 3)
# Frame :  350 / 714  - Tracked points:  198
# (2, 3)
# Frame :  351 / 714  - Tracked points:  195
# (2, 3)
# Frame :  352 / 714  - Tracked points:  199
# (2, 3)
# Frame :  353 / 714  - Tracked points:  186
# (2, 3)
# Frame :  354 / 714  - Tracked points:  191
# (2, 3)
# Frame :  355 / 714  - Tracked points:  200
# (2, 3)
# Frame :  356 / 714  - Tracked points:  200
# (2, 3)
# Frame :  357 / 714  - Tracked points:  200
# (2, 3)
# Frame :  358 / 714  - Tracked points:  200
# (2, 3)
# Frame :  359 / 714  - Tracked points:  197
# (2, 3)
# Frame :  360 / 714  - Tracked points:  196
# (2, 3)
# Frame :  361 / 714  - Tracked points:  200
# (2, 3)
# Frame :  362 / 714  - Tracked points:  200
# (2, 3)
# Frame :  363 / 714  - Tracked points:  197
# (2, 3)
# Frame :  364 / 714  - Tracked points:  192
# (2, 3)
# Frame :  365 / 714  - Tracked points:  189
# (2, 3)
# Frame :  366 / 714  - Tracked points:  198
# (2, 3)
# Frame :  367 / 714  - Tracked points:  195
# (2, 3)
# Frame :  368 / 714  - Tracked points:  191
# (2, 3)
# Frame :  369 / 714  - Tracked points:  197
# (2, 3)
# Frame :  370 / 714  - Tracked points:  200
# (2, 3)
# Frame :  371 / 714  - Tracked points:  195
# (2, 3)
# Frame :  372 / 714  - Tracked points:  187
# (2, 3)
# Frame :  373 / 714  - Tracked points:  199
# (2, 3)
# Frame :  374 / 714  - Tracked points:  196
# (2, 3)
# Frame :  375 / 714  - Tracked points:  193
# (2, 3)
# Frame :  376 / 714  - Tracked points:  198
# (2, 3)
# Frame :  377 / 714  - Tracked points:  197
# (2, 3)
# Frame :  378 / 714  - Tracked points:  200
# (2, 3)
# Frame :  379 / 714  - Tracked points:  199
# (2, 3)
# Frame :  380 / 714  - Tracked points:  193
# (2, 3)
# Frame :  381 / 714  - Tracked points:  196
# (2, 3)
# Frame :  382 / 714  - Tracked points:  193
# (2, 3)
# Frame :  383 / 714  - Tracked points:  190
# (2, 3)
# Frame :  384 / 714  - Tracked points:  177
# (2, 3)
# Frame :  385 / 714  - Tracked points:  200
# (2, 3)
# Frame :  386 / 714  - Tracked points:  158
# (2, 3)
# Frame :  387 / 714  - Tracked points:  186
# (2, 3)
# Frame :  388 / 714  - Tracked points:  165
# (2, 3)
# Frame :  389 / 714  - Tracked points:  193
# (2, 3)
# Frame :  390 / 714  - Tracked points:  193
# (2, 3)
# Frame :  391 / 714  - Tracked points:  181
# (2, 3)
# Frame :  392 / 714  - Tracked points:  190
# (2, 3)
# Frame :  393 / 714  - Tracked points:  200
# (2, 3)
# Frame :  394 / 714  - Tracked points:  197
# (2, 3)
# Frame :  395 / 714  - Tracked points:  197
# (2, 3)
# Frame :  396 / 714  - Tracked points:  190
# (2, 3)
# Frame :  397 / 714  - Tracked points:  200
# (2, 3)
# Frame :  398 / 714  - Tracked points:  180
# (2, 3)
# Frame :  399 / 714  - Tracked points:  199
# (2, 3)
# Frame :  400 / 714  - Tracked points:  174
# (2, 3)
# Frame :  401 / 714  - Tracked points:  196
# (2, 3)
# Frame :  402 / 714  - Tracked points:  199
# (2, 3)
# Frame :  403 / 714  - Tracked points:  196
# (2, 3)
# Frame :  404 / 714  - Tracked points:  194
# (2, 3)
# Frame :  405 / 714  - Tracked points:  190
# (2, 3)
# Frame :  406 / 714  - Tracked points:  197
# (2, 3)
# Frame :  407 / 714  - Tracked points:  189
# (2, 3)
# Frame :  408 / 714  - Tracked points:  195
# (2, 3)
# Frame :  409 / 714  - Tracked points:  182
# (2, 3)
# Frame :  410 / 714  - Tracked points:  187
# (2, 3)
# Frame :  411 / 714  - Tracked points:  191
# (2, 3)
# Frame :  412 / 714  - Tracked points:  199
# (2, 3)
# Frame :  413 / 714  - Tracked points:  200
# (2, 3)
# Frame :  414 / 714  - Tracked points:  196
# (2, 3)
# Frame :  415 / 714  - Tracked points:  193
# (2, 3)
# Frame :  416 / 714  - Tracked points:  200
# (2, 3)
# Frame :  417 / 714  - Tracked points:  195
# (2, 3)
# Frame :  418 / 714  - Tracked points:  199
# (2, 3)
# Frame :  419 / 714  - Tracked points:  173
# (2, 3)
# Frame :  420 / 714  - Tracked points:  200
# (2, 3)
# Frame :  421 / 714  - Tracked points:  198
# (2, 3)
# Frame :  422 / 714  - Tracked points:  199
# (2, 3)
# Frame :  423 / 714  - Tracked points:  187
# (2, 3)
# Frame :  424 / 714  - Tracked points:  186
# (2, 3)
# Frame :  425 / 714  - Tracked points:  166
# (2, 3)
# Frame :  426 / 714  - Tracked points:  198
# (2, 3)
# Frame :  427 / 714  - Tracked points:  179
# (2, 3)
# Frame :  428 / 714  - Tracked points:  189
# (2, 3)
# Frame :  429 / 714  - Tracked points:  196
# (2, 3)
# Frame :  430 / 714  - Tracked points:  173
# (2, 3)
# Frame :  431 / 714  - Tracked points:  176
# (2, 3)
# Frame :  432 / 714  - Tracked points:  184
# (2, 3)
# Frame :  433 / 714  - Tracked points:  199
# (2, 3)
# Frame :  434 / 714  - Tracked points:  195
# (2, 3)
# Frame :  435 / 714  - Tracked points:  188
# (2, 3)
# Frame :  436 / 714  - Tracked points:  182
# (2, 3)
# Frame :  437 / 714  - Tracked points:  195
# (2, 3)
# Frame :  438 / 714  - Tracked points:  197
# (2, 3)
# Frame :  439 / 714  - Tracked points:  198
# (2, 3)
# Frame :  440 / 714  - Tracked points:  192
# (2, 3)
# Frame :  441 / 714  - Tracked points:  197
# (2, 3)
# Frame :  442 / 714  - Tracked points:  195
# (2, 3)
# Frame :  443 / 714  - Tracked points:  197
# (2, 3)
# Frame :  444 / 714  - Tracked points:  194
# (2, 3)
# Frame :  445 / 714  - Tracked points:  184
# (2, 3)
# Frame :  446 / 714  - Tracked points:  172
# (2, 3)
# Frame :  447 / 714  - Tracked points:  192
# (2, 3)
# Frame :  448 / 714  - Tracked points:  199
# (2, 3)
# Frame :  449 / 714  - Tracked points:  197
# (2, 3)
# Frame :  450 / 714  - Tracked points:  200
# (2, 3)
# Frame :  451 / 714  - Tracked points:  197
# (2, 3)
# Frame :  452 / 714  - Tracked points:  196
# (2, 3)
# Frame :  453 / 714  - Tracked points:  198
# (2, 3)
# Frame :  454 / 714  - Tracked points:  187
# (2, 3)
# Frame :  455 / 714  - Tracked points:  193
# (2, 3)
# Frame :  456 / 714  - Tracked points:  196
# (2, 3)
# Frame :  457 / 714  - Tracked points:  182
# (2, 3)
# Frame :  458 / 714  - Tracked points:  200
# (2, 3)
# Frame :  459 / 714  - Tracked points:  189
# (2, 3)
# Frame :  460 / 714  - Tracked points:  198
# (2, 3)
# Frame :  461 / 714  - Tracked points:  192
# (2, 3)
# Frame :  462 / 714  - Tracked points:  184
# (2, 3)
# Frame :  463 / 714  - Tracked points:  189
# (2, 3)
# Frame :  464 / 714  - Tracked points:  190
# (2, 3)
# Frame :  465 / 714  - Tracked points:  188
# (2, 3)
# Frame :  466 / 714  - Tracked points:  197
# (2, 3)
# Frame :  467 / 714  - Tracked points:  185
# (2, 3)
# Frame :  468 / 714  - Tracked points:  177
# (2, 3)
# Frame :  469 / 714  - Tracked points:  175
# (2, 3)
# Frame :  470 / 714  - Tracked points:  192
# (2, 3)
# Frame :  471 / 714  - Tracked points:  198
# (2, 3)
# Frame :  472 / 714  - Tracked points:  174
# (2, 3)
# Frame :  473 / 714  - Tracked points:  194
# (2, 3)
# Frame :  474 / 714  - Tracked points:  168
# (2, 3)
# Frame :  475 / 714  - Tracked points:  188
# (2, 3)
# Frame :  476 / 714  - Tracked points:  191
# (2, 3)
# Frame :  477 / 714  - Tracked points:  190
# (2, 3)
# Frame :  478 / 714  - Tracked points:  147
# (2, 3)
# Frame :  479 / 714  - Tracked points:  180
# (2, 3)
# Frame :  480 / 714  - Tracked points:  191
# (2, 3)
# Frame :  481 / 714  - Tracked points:  180
# (2, 3)
# Frame :  482 / 714  - Tracked points:  185
# (2, 3)
# Frame :  483 / 714  - Tracked points:  144
# (2, 3)
# Frame :  484 / 714  - Tracked points:  191
# (2, 3)
# Frame :  485 / 714  - Tracked points:  189
# (2, 3)
# Frame :  486 / 714  - Tracked points:  189
# (2, 3)
# Frame :  487 / 714  - Tracked points:  189
# (2, 3)
# Frame :  488 / 714  - Tracked points:  196
# (2, 3)
# Frame :  489 / 714  - Tracked points:  190
# (2, 3)
# Frame :  490 / 714  - Tracked points:  160
# (2, 3)
# Frame :  491 / 714  - Tracked points:  193
# (2, 3)
# Frame :  492 / 714  - Tracked points:  170
# (2, 3)
# Frame :  493 / 714  - Tracked points:  199
# (2, 3)
# Frame :  494 / 714  - Tracked points:  197
# (2, 3)
# Frame :  495 / 714  - Tracked points:  188
# (2, 3)
# Frame :  496 / 714  - Tracked points:  199
# (2, 3)
# Frame :  497 / 714  - Tracked points:  191
# (2, 3)
# Frame :  498 / 714  - Tracked points:  199
# (2, 3)
# Frame :  499 / 714  - Tracked points:  185
# (2, 3)
# Frame :  500 / 714  - Tracked points:  189

# %%
#caculate trajectory between frames
trajectory = np.cumsum(transforms,axis=0)

# %%
def movingAverage(curve, radius): 
  window_size = 2 * radius + 1
  # Define the filter 
  f = np.ones(window_size)/window_size 
  # Add padding to the boundaries 
  curve_pad = np.lib.pad(curve, (radius, radius), 'edge') 
  # Apply convolution 
  curve_smoothed = np.convolve(curve_pad, f, mode='same') 
  # Remove padding 
  curve_smoothed = curve_smoothed[radius:-radius]
  # return smoothed curve
  return curve_smoothed

# %%
def smooth(trajectory): 
  smoothed_trajectory = np.copy(trajectory) 
  SMOOTHING_RADIUS = 20
  # Filter the x, y and angle curves
  for i in range(3):
    smoothed_trajectory[:,i] = movingAverage(trajectory[:,i], radius=SMOOTHING_RADIUS)

  return smoothed_trajectory

# %%
# Compute trajectory using cumulative sum of transformations
smoothed_trajectory = smooth(trajectory)
difference = smoothed_trajectory - trajectory
transforms_smooth = transforms + difference

# %%
# Reset stream to first frame 
cap.set(cv2.CAP_PROP_POS_FRAMES, 0) 
 
# Write n_frames-1 transformed frames
for i in range(frame_count-2):
  # Read next frame
  success, frame = cap.read() 
  if not success:
    break
  mean_thresh, blurry = detect_blur_fft(curr_gray,thresh=25)
  if (blurry == True):
    continue
  # Extract transformations from the new transformation array
  dx = transforms_smooth[i,0]
  dy = transforms_smooth[i,1]
  da = transforms_smooth[i,2]

  # Reconstruct transformation matrix accordingly to new values
  m = np.zeros((2,3), np.float32)
  m[0,0] = np.cos(da)
  m[0,1] = -np.sin(da)
  m[1,0] = np.sin(da)
  m[1,1] = np.cos(da)
  m[0,2] = dx
  m[1,2] = dy

  # Apply affine wrapping to the given frame
  frame_stabilized = cv2.warpAffine(frame, m, (width,height))

  # Fix border artifacts
  frame_stabilized = fixBorder(frame_stabilized) 

  # Write the frame to the file
  frame_out = cv2.hconcat([frame, frame_stabilized])
  #print(frame_out.shape[0],frame_out.shape[1])

  # If the image is too big, resize it.
  if(frame_out.shape[1] > 1280): 
    frame_out = cv2.resize(frame_out, (int(frame_out.shape[1]/2), int(frame_out.shape[0])));
  print("Frame number:", i, frame_out.shape)
  #cv2_imshow(frame_out)
  #cv2.waitKey(10)
  print(frame_out.shape)
  try:
     output_video.write(frame_out)
  except e:
    print("An error has occured:", e)
output_video.release()
print('Processing finished')
# Out:
# Processing finished

# %%
end_time = timer()
print('Total Elapsed time =:',end_time-start_time)
# Out:
# Total Elapsed time =: 287.38303801099937

# %%
def fixBorder(frame):
  s = frame.shape
  # Scale the image 4% without moving the center
  T = cv2.getRotationMatrix2D((s[1]/2, s[0]/2), 0, 1.04)
  frame = cv2.warpAffine(frame, T, (s[1], s[0]))
  return frame
